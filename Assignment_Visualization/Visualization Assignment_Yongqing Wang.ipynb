# %% [markdown]
# # Git commands

# %%
# git config --global --add safe.directory 'E:/.Trashes/Grey SSD/教育/Graduate School/French Universities/NEOMA/Machine Learning and Deep Learning/Assignment_Visualization'
# git remote add origin https://github.com/kayla-dsrepo/Academic-Projects.git
# git remote set-url origin git@github.com:kayla-dsrepo/Academic-Projects.git

# git push -u -f origin master

# git commit -m "initial commit"

# %% [markdown]
# # Notes

# %% [markdown]
# Link
# - https://catalog.data.gov/dataset/behavioral-health-and-workforce
# - https://catalog.data.gov/dataset/state-drug-utilization-data-2024
#
#
#
#
#
# "Medicare is mainly designed for those 65 and older and people with disabilities, while Medicaid is for people with qualifying low income at any age."
#
#
# Sanofi drugs: dupixent, lantus, ALTUVIIIO , Beyfortus, Toujeo
#
# Competitors of Sanofi drugs: Nucala|Fasenra|Astegolimab|Eohilia|Semglee|Tresiba|Basaglar|Levemir|Hemlibra|Roctavian|Hympavzi|Clesrovimab|Arexvy

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import glob
import re
import datetime as dt

# %% [markdown]
# # Process

# %%
df = pd.read_csv("Datasets\SDUD-2024.csv")
df.head()
# Out:
#   Utilization Type State      NDC  Labeler Code  Product Code  Package Size  \
# 0             FFSU    AK  2143380             2          1433            80
# 1             FFSU    AK  2143480             2          1434            80
# 2             FFSU    AK  2143611             2          1436            11
# 3             FFSU    AK  2144509             2          1445             9
# 4             FFSU    AK  2144511             2          1445            11
#
#    Year  Quarter  Suppression Used Product Name  Units Reimbursed  \
# 0  2024        4             False   TRULICITY              230.0
# 1  2024        4             False   TRULICITY              216.0
# 2  2024        4             False   EMGALITY P              32.0
# 3  2024        4              True   TALTZ AUTO               NaN
# 4  2024        4             False   TALTZ AUTO              38.0
#
#    Number of Prescriptions  Total Amount Reimbursed  \
# 0                    110.0                108512.57
# ...

# %%
len(set(df['Product Name']))

df[df['Product Name'].str.contains(r'dupix|lantus|ALTUVIIIO|Beyfortus|Toujeo',case=False)].sample(5)
# Out:
#         Utilization Type State          NDC  Labeler Code  Product Code  \
# 4169141             MCOU    PA  71104098401         71104           984
# 2838632             FFSU    XX  71104098201         71104           982
# 178636              FFSU    AR  71104098401         71104           984
# 917122              FFSU    GA     88221905            88          2219
# 3442294             FFSU    NM     24591401            24          5914
#
#          Package Size  Year  Quarter  Suppression Used Product Name  \
# 4169141             1  2024        2             False   ALTUVIIIO
# 2838632             1  2024        2             False   ALTUVIIIO
# 178636              1  2024        2              True   ALTUVIIIO
# 917122              5  2024        3             False   LANTUS SOL
# 3442294             1  2024        1             False   DUPIXENT 3
#
#          Units Reimbursed  Number of Prescriptions  Total Amount Reimbursed  \
# ...
